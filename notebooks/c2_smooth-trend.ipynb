# %% [markdown]
# # 概要
#
# * アタポンの1位データに絞る
# * ちょうど毎月開催されてるので、月次にしてみる
#   * 「月の中で何日に開催された」とかは一旦考慮しない
# * 平滑化トレンドモデルにしてみる

# %% [markdown]
# # インポート

# %%
import numpy as np
import pandas as pd
import pickle
import datetime
from datetime import timedelta
import matplotlib as mpl
import matplotlib.pyplot as plt
import seaborn as sns
sns.set(font=['IPAMincho'])
from sklearn.metrics import r2_score

import pystan

# %% [markdown]
# # イベントデータ読み込み

# %%
input_dir = './data/'

# %%
df = pd.read_pickle(input_dir + 'a3_output_df.pkl')
df = df[df['形式'] == 'アタポン'].set_index('日付')
df
# Out:
#                               イベント       1位   2001位    形式   属性     期間
# 日付
# 2015-09-25           アタシポンコツアンドロイド   427777   78330  アタポン  NaN  249.0
# 2015-10-19             Nation Blue   324369   67627  アタポン  NaN  198.0
# 2015-11-20         Orange Sapphire   350000   42944  アタポン  NaN  150.0
# 2015-12-18              Snow Wings   520000   50954  アタポン  NaN  222.0
# 2016-01-20               パステルピンクな恋   602529   43854  アタポン  NaN  174.0
# 2016-02-18                オルゴールの小箱   523819   56737  アタポン  NaN  174.0
# 2016-03-20             絶対特権主張しますっ！   530000   51353  アタポン  NaN  174.0
# 2016-04-19                     つぼみ   666666   47907  アタポン  NaN  174.0
# 2016-05-19               明日また会えるよね   844167   58517  アタポン  NaN  198.0
# 2016-06-20                咲いてJewel   650152   77930  アタポン  NaN  174.0
# 2016-07-19                きみにいっぱい☆   615000   50759  アタポン  NaN  198.0
# 2016-08-19             Near to You   760307   46355  アタポン  NaN  198.0
# 2016-09-20                   ラブレター   596000  121303  アタポン  NaN  150.0
# 2016-10-20       Jet to the Future   609969   69430  アタポン  NaN  174.0
# 2016-11-19               Flip Flop   700000   64568  アタポン  NaN  198.0
# 2016-12-21               あんきら!?狂騒曲   694253   91619  アタポン  NaN  150.0
# 2017-01-20            Lunatic Show   684784  103834  アタポン  NaN  174.0
# 2017-02-17            情熱ファンファンファーレ   881000   87731  アタポン  NaN  198.0
# 2017-03-21                  ∀NSWER   715889   77131  アタポン  NaN  174.0
# 2017-04-19                Nocturne   711125   64224  アタポン  NaN  174.0
# 2017-05-19           モーレツ★世直しギルティ！   917400   85036  アタポン  NaN  222.0
# 2017-06-19       Yes！ Party Time！！   721149  102781  アタポン  NaN  174.0
# 2017-07-20     Kawaii make MY day！   775836   70863  アタポン  NaN  174.0
# 2017-08-21                  双翼の独奏歌   709450  156206  アタポン  NaN  150.0
# 2017-09-20            Twin☆くるっ★テール   807041  114084  アタポン  NaN  174.0
# 2017-10-20          Halloween♥Code   844167   89011  アタポン  NaN  174.0
# 2017-11-19           Trinity Field   783042  193847  アタポン  NaN  174.0
# 2017-12-20                 冬空プレシャス   765000   63299  アタポン  NaN  174.0
# 2018-01-12                美に入り彩を穿つ   748760  112616  アタポン  NaN  150.0
# 2018-02-19                   Frost   679865   93945  アタポン  NaN  150.0
# 2018-03-20              キラッ！満開スマイル   932639  144198  アタポン  NaN  198.0
# 2018-04-19        Spring Screaming   825782   67629  アタポン  NaN  174.0
# 2018-05-21              HARURUNRUN   751205   58907  アタポン  NaN  174.0
# 2018-06-19              エチュードは1曲だけ   817257   86964  アタポン  NaN  174.0
# 2018-07-19              SUN♡FLOWER   942493   74511  アタポン  NaN  198.0
# 2018-08-19              クレイジークレイジー   925686  163641  アタポン  NaN  198.0
# 2018-09-19             Pretty Liar   954312  224697  アタポン  NaN  198.0
# 2018-10-19            アンデッド・ダンスロック   974760   83532  アタポン  NaN  198.0
# 2018-11-19        Sunshine See May   945614  156519  アタポン  NaN  198.0
# 2018-12-19                Trust me   978776   78278  アタポン  NaN  198.0
# 2019-01-21               スパイスパラダイス   883242  179632  アタポン  NaN  174.0
# 2019-02-19            Needle Light   730000   67182  アタポン  NaN  150.0
# 2019-03-20                  未完成の歴史   886578  143192  アタポン  NaN  174.0
# 2019-04-19            きゅん・きゅん・まっくす   870742   73887  アタポン  NaN  174.0
# 2019-05-21                Max Beat   910638   68476  アタポン  NaN  174.0
# 2019-06-21  TAKAMARI☆CLIMAXXX！！！！！   936000   72590  アタポン  NaN  198.0
# 2019-07-22                    バベル   1059763  151703  アタポン  NaN  157.0
# 2019-08-20            comic cosmic  1129958   82849  アタポン  NaN  174.0
# 2019-09-20               ステップ＆スキップ  1161870  147582  アタポン  NaN  174.0
# 2019-10-21                  空想探査計画  1100000   71393  アタポン  NaN  174.0
# 2019-11-20         Secret Daybreak  1180231  169639  アタポン  NaN  175.0
# 2019-12-20           ギュっとMilky Way  1111111   99081  アタポン  NaN  174.0
# 2020-01-20             幸せの法則 ～ルール～  1268425  115890  アタポン  NaN  198.0
# 2020-02-18                      印象  1424681   76797  アタポン  NaN  198.0
# 2020-03-21            輝け！ビートシューター   1330000   84545  アタポン  NaN  198.0
# 2020-04-20               Athanasia  1130000   75775  アタポン  NaN  174.0
# 2020-05-19               不埒なCANVAS  1271125  188652  アタポン  NaN  198.0
# 2020-06-19      Sing the Prologue♪  1123140   85574  アタポン  NaN  174.0
# 2020-07-20                 太陽の絵の具箱  1120703  107142  アタポン  NaN  174.0
# 2020-08-19        ヒーローヴァーサスレイナンジョー  1250000   60211  アタポン  NaN  174.0

# %%
# プロットしてみる
fig = plt.figure()
ax = fig.add_subplot(111)
x = df.index
y = df.loc[:, '1位']
ax.plot(x, y)
plt.show()
# Out:
# WARNING:matplotlib.font_manager:findfont: Font family ['IPAMincho'] not found. Falling back to DejaVu Sans.

# %% [markdown]
# # stanデータ準備

# %%
# データ（辞書型）
dat = {
    'T':       len(df),         # 全日付の日数
    'y':       df['1位'].tolist(), # 観測値
}

# %%
# Stanコード
model = """
data {
  int T;                   // データ取得期間の長さ
  vector[T] y;       // 観測値
}
parameters {
  vector[T] mu;
  real<lower=0> s_w;
  real<lower=0> s_v;
}
model {
  for(i in 3:T){
    mu[i] ~ normal(2*mu[i-1] - mu[i-2], s_w);
    y[i] ~ normal(mu[i], s_v);
  }
}
"""

# %% [markdown]
# # Stan実行

# %%
# コンパイル
# %time stm = pystan.StanModel(model_code=model)
# Out:
# INFO:pystan:COMPILING THE C++ CODE FOR MODEL anon_model_3740aced05cf22d96ac4408a74567f91 NOW.
# C:\Users\kazuy\Anaconda3\lib\site-packages\Cython\Compiler\Main.py:369: FutureWarning: Cython directive 'language_level' not set, using 2 for now (Py2). This will change in a later release! File: C:\Users\kazuy\AppData\Local\Temp\tmpvaza7r3y\stanfit4anon_model_3740aced05cf22d96ac4408a74567f91_2900365102922135676.pyx
#   tree = Parsing.p_module(s, pxd, full_module_name)
# Wall time: 27.1 s

# %%
# パラメータ設定
n_itr = 5000
n_warmup = n_itr - 1000
chains = 3

# %%
# 計算
# %time fit = stm.sampling(data=dat, iter=n_itr, chains=chains, n_jobs=-1, warmup=n_warmup, algorithm="NUTS", verbose=False)
# Out:
# Wall time: 29.7 s

# %%
# ファイル保存
save_dir = './data/'
with open(save_dir + 'c2_model.pickle', mode="wb") as f:
    pickle.dump(stm, f)
with open(save_dir + 'c2_fit.pickle', mode="wb") as f:
    pickle.dump(fit, f)
# Out:
# C:\Users\kazuy\Anaconda3\lib\site-packages\ipykernel_launcher.py:6: UserWarning: Pickling fit objects is an experimental feature!
# The relevant StanModel instance must be pickled along with this fit object.
# When unpickling the StanModel must be unpickled first.

# %% [markdown]
# # 結果確認

# %%
fit
# Out:
# Inference for Stan model: anon_model_3740aced05cf22d96ac4408a74567f91.
# 3 chains, each with iter=5000; warmup=4000; thin=1;
# post-warmup draws per chain=1000, total post-warmup draws=3000.
#
#          mean se_mean     sd   2.5%    25%    50%    75%  97.5%  n_eff   Rhat
# mu[0]   4.0e5   4.4e4  1.1e5  1.5e5  3.3e5  4.2e5  5.0e5  5.5e5      6   1.17
# mu[1]   4.3e5   3.7e4  8.4e4  2.5e5  3.8e5  4.5e5  5.1e5  5.5e5      5   1.17
# mu[2]   4.7e5   2.5e4  6.2e4  3.4e5  4.2e5  4.8e5  5.2e5  5.6e5      6   1.16
# mu[3]   5.0e5   1.7e4  4.5e4  4.1e5  4.7e5  5.1e5  5.4e5  5.8e5      7   1.11
# mu[4]   5.4e5  5690.4  3.5e4  4.6e5  5.1e5  5.5e5  5.6e5  6.0e5     37   1.04
# mu[5]   5.7e5  967.21  3.1e4  5.0e5  5.5e5  5.7e5  5.9e5  6.3e5   1012    1.0
# mu[6]   6.0e5  2844.1  3.2e4  5.4e5  5.8e5  5.9e5  6.2e5  6.7e5    123   1.03
# mu[7]   6.2e5   1.0e4  3.5e4  5.6e5  6.0e5  6.1e5  6.4e5  7.0e5     11   1.09
# mu[8]   6.4e5   1.4e4  3.7e4  5.9e5  6.1e5  6.4e5  6.7e5  7.3e5      7   1.14
# mu[9]   6.5e5   1.5e4  3.6e4  6.0e5  6.2e5  6.5e5  6.8e5  7.3e5      6   1.17
# mu[10]  6.6e5   1.4e4  3.4e4  6.1e5  6.3e5  6.6e5  6.9e5  7.3e5      6   1.18
# mu[11]  6.7e5   1.2e4  3.3e4  6.2e5  6.4e5  6.7e5  6.9e5  7.4e5      7   1.16
# mu[12]  6.8e5   1.1e4  3.2e4  6.2e5  6.5e5  6.7e5  7.0e5  7.4e5      9   1.12
# mu[13]  6.9e5  9808.0  3.3e4  6.3e5  6.6e5  6.8e5  7.1e5  7.5e5     11   1.11
# mu[14]  7.0e5  9312.4  3.2e4  6.4e5  6.7e5  6.9e5  7.2e5  7.6e5     12    1.1
# mu[15]  7.1e5  9166.9  3.2e4  6.5e5  6.8e5  7.0e5  7.3e5  7.8e5     12    1.1
# mu[16]  7.2e5  9810.3  3.1e4  6.7e5  7.0e5  7.2e5  7.5e5  7.9e5     10   1.11
# mu[17]  7.4e5   1.0e4  3.0e4  6.9e5  7.1e5  7.3e5  7.6e5  8.0e5      9   1.11
# mu[18]  7.5e5  9502.9  3.0e4  7.0e5  7.3e5  7.4e5  7.7e5  8.1e5     10   1.09
# mu[19]  7.6e5  8095.7  2.9e4  7.1e5  7.4e5  7.5e5  7.8e5  8.2e5     13   1.07
# mu[20]  7.7e5  5519.0  2.9e4  7.1e5  7.5e5  7.6e5  7.8e5  8.3e5     27   1.04
# mu[21]  7.7e5  952.72  2.7e4  7.1e5  7.6e5  7.7e5  7.9e5  8.3e5    828   1.01
# mu[22]  7.7e5  560.44  2.7e4  7.2e5  7.6e5  7.8e5  7.9e5  8.3e5   2339    1.0
# mu[23]  7.8e5  1238.7  2.8e4  7.2e5  7.6e5  7.8e5  7.9e5  8.3e5    500   1.01
# mu[24]  7.8e5  4320.5  2.9e4  7.2e5  7.7e5  7.9e5  8.0e5  8.4e5     45   1.04
# mu[25]  7.9e5  8446.2  3.0e4  7.2e5  7.7e5  7.9e5  8.1e5  8.4e5     13   1.08
# mu[26]  7.9e5   1.1e4  3.2e4  7.2e5  7.7e5  8.0e5  8.2e5  8.4e5      8   1.13
# mu[27]  8.0e5   1.4e4  3.4e4  7.2e5  7.7e5  8.0e5  8.3e5  8.5e5      6   1.19
# mu[28]  8.0e5   1.6e4  3.6e4  7.3e5  7.8e5  8.0e5  8.4e5  8.5e5      5   1.24
# mu[29]  8.1e5   1.6e4  3.6e4  7.4e5  7.9e5  8.1e5  8.5e5  8.6e5      5   1.25
# mu[30]  8.2e5   1.5e4  3.4e4  7.5e5  8.0e5  8.2e5  8.6e5  8.7e5      5   1.24
# mu[31]  8.4e5   1.4e4  3.3e4  7.7e5  8.1e5  8.4e5  8.7e5  8.8e5      6   1.21
# mu[32]  8.5e5   1.2e4  3.2e4  7.8e5  8.3e5  8.5e5  8.8e5  9.0e5      7   1.16
# mu[33]  8.7e5  8976.3  3.1e4  8.0e5  8.4e5  8.7e5  8.9e5  9.2e5     12    1.1
# mu[34]  8.8e5  5316.1  3.1e4  8.2e5  8.6e5  8.9e5  9.0e5  9.4e5     34   1.05
# mu[35]  8.9e5  2562.3  3.2e4  8.3e5  8.7e5  9.0e5  9.1e5  9.6e5    157   1.02
# mu[36]  9.1e5  2047.1  3.3e4  8.4e5  8.8e5  9.1e5  9.2e5  9.7e5    256   1.01
# mu[37]  9.1e5  1900.8  3.2e4  8.5e5  8.9e5  9.2e5  9.2e5  9.8e5    286   1.02
# mu[38]  9.1e5  5098.0  3.1e4  8.5e5  8.9e5  9.2e5  9.3e5  9.7e5     37   1.04
# mu[39]  9.1e5   1.0e4  3.1e4  8.5e5  8.9e5  9.2e5  9.4e5  9.7e5      9    1.1
# mu[40]  9.1e5   1.6e4  3.5e4  8.4e5  8.9e5  9.2e5  9.5e5  9.7e5      5   1.19
# mu[41]  9.2e5   1.8e4  4.0e4  8.3e5  8.9e5  9.2e5  9.6e5  9.8e5      5   1.21
# mu[42]  9.3e5   1.9e4  4.2e4  8.4e5  9.0e5  9.3e5  9.6e5 10.0e5      5   1.19
# mu[43]  9.4e5   1.6e4  4.0e4  8.6e5  9.2e5  9.5e5  9.7e5  1.0e6      6   1.14
# mu[44]  9.7e5   1.1e4  3.5e4  8.9e5  9.4e5  9.8e5  9.9e5  1.0e6     10   1.07
# mu[45] 10.0e5  2039.9  3.0e4  9.3e5  9.8e5 10.0e5  1.0e6  1.1e6    221   1.02
# mu[46]  1.0e6  4033.7  2.9e4  9.7e5  1.0e6  1.0e6  1.0e6  1.1e6     51   1.05
# mu[47]  1.1e6   1.1e4  3.2e4  1.0e6  1.0e6  1.1e6  1.1e6  1.1e6      8   1.19
# mu[48]  1.1e6   1.9e4  3.7e4  1.0e6  1.1e6  1.1e6  1.1e6  1.2e6      4   1.33
# mu[49]  1.1e6   2.1e4  4.3e4  1.1e6  1.1e6  1.1e6  1.2e6  1.2e6      4   1.43
# mu[50]  1.1e6   2.8e4  4.8e4  1.1e6  1.1e6  1.2e6  1.2e6  1.2e6      3    1.5
# mu[51]  1.2e6   3.1e4  5.3e4  1.1e6  1.1e6  1.2e6  1.2e6  1.3e6      3   1.53
# mu[52]  1.2e6   3.2e4  5.6e4  1.1e6  1.1e6  1.2e6  1.2e6  1.3e6      3   1.51
# mu[53]  1.2e6   3.2e4  5.5e4  1.1e6  1.2e6  1.2e6  1.2e6  1.3e6      3   1.48
# mu[54]  1.2e6   2.8e4  4.8e4  1.2e6  1.2e6  1.2e6  1.3e6  1.3e6      3   1.43
# mu[55]  1.2e6   1.9e4  3.8e4  1.2e6  1.2e6  1.2e6  1.2e6  1.3e6      4    1.3
# mu[56]  1.2e6  9947.4  3.1e4  1.2e6  1.2e6  1.2e6  1.2e6  1.3e6     10   1.11
# mu[57]  1.2e6  1201.4  3.2e4  1.2e6  1.2e6  1.2e6  1.2e6  1.3e6    712    1.0
# mu[58]  1.2e6  4510.1  4.1e4  1.1e6  1.2e6  1.2e6  1.2e6  1.3e6     82   1.04
# mu[59]  1.2e6   1.7e4  5.6e4  1.1e6  1.2e6  1.2e6  1.3e6  1.3e6     11   1.08
# s_w     1.0e4  3766.7 7533.4 1465.7 3981.5 9053.6  1.5e4  2.7e4      4   1.31
# s_v     9.1e4  5920.8  1.2e4  7.0e4  8.2e4  8.9e4  1.0e5  1.1e5      4   1.28
# lp__    -1211   35.38  50.03  -1282  -1251  -1225  -1179  -1125      2   1.85
#
# Samples were drawn using NUTS at Thu Nov 19 12:55:34 2020.
# For each parameter, n_eff is a crude measure of effective sample size,
# and Rhat is the potential scale reduction factor on split chains (at
# convergence, Rhat=1).

# %%
fit.plot()
# Out:
# WARNING:matplotlib.font_manager:findfont: Font family ['IPAMincho'] not found. Falling back to DejaVu Sans.

# %%
#結果を抽出
ms = fit.extract() 

#muの事後平均を算出
mu_mean = ms['mu'].mean(axis=0)

#95パーセンタイルを抽出
mu_5 = np.array(pd.DataFrame(ms['mu']).apply(lambda x: np.percentile(x, 5), axis=0))
mu_95 = np.array(pd.DataFrame(ms['mu']).apply(lambda x: np.percentile(x, 95), axis=0))

#x軸
X = df.index

# %%
fig = plt.figure()
ax = fig.add_subplot(111)

ax.plot(X, df['1位'], label='observed')
# ax.plot(X, mu, label='true trend', c='green')
ax.plot(X, mu_mean, label='predicted trend', c='red')
plt.fill_between(X, mu_5, mu_95, color='red', alpha=0.2)
# plt.legend(loc='upper left', borderaxespad=0, fontsize=15)
plt.show()

# %% [markdown]
# ローカルレベルモデルよりはスムーズにつなぎにいくため、過去のデータでは外れるものが多くなっている

# %% [markdown]
# # 残差確認

# %%
df['predict'] = mu_mean
# 予測とのズレ（比）
df['diff'] = df['1位'] - df['predict']
df.drop(['2001位', '形式', '属性'], axis=1, inplace=True)
# Out:
# INFO:numexpr.utils:NumExpr defaulting to 6 threads.

# %%
df.head()
# Out:
#                        イベント      1位     期間        predict           diff
# 日付
# 2015-09-25    アタシポンコツアンドロイド  427777  249.0  400629.754816   27147.245184
# 2015-10-19      Nation Blue  324369  198.0  434794.533646 -110425.533646
# 2015-11-20  Orange Sapphire  350000  150.0  469429.692274 -119429.692274
# 2015-12-18       Snow Wings  520000  222.0  504306.119921   15693.880079
# 2016-01-20        パステルピンクな恋  602529  174.0  537342.238850   65186.761150

# %%
# 決定係数 (R2)
r2_score(df['1位'], df['predict'])
# Out:
# 0.8870694653111069

# %%
fig, ax = plt.subplots(1, 1)
ax.scatter(df['1位'], df['predict'])
ideal_min = min(df['1位'].min(), df['predict'].min())
ideal_max = min(df['1位'].max(), df['predict'].max())
ax.plot([ideal_min, ideal_max], [ideal_min, ideal_max], color='r')
plt.show()

# %%
df.corr()
# Out:
#                1位        期間   predict      diff
# 1位       1.000000  0.100235  0.942606  0.437596
# 期間       0.100235  1.000000 -0.098162  0.562632
# predict  0.942606 -0.098162  1.000000  0.112241
# diff     0.437596  0.562632  0.112241  1.000000

# %%
# 期間と相関あり
sns.set(font='Yu Gothic')
sns.pairplot(df)
