# %% [markdown]
# # 概要
#
# * アタポンの1位データに絞る
# * ちょうど毎月開催されてるので、月次にしてみる
#   * 「月の中で何日に開催された」とかは一旦考慮しない
# * ローカル線形トレンドモデルにしてみる

# %% [markdown]
# # インポート

# %%
import numpy as np
import pandas as pd
import pickle
import datetime
from datetime import timedelta
import matplotlib as mpl
import matplotlib.pyplot as plt
import seaborn as sns
sns.set(font=['IPAMincho'])
from sklearn.metrics import r2_score

import pystan

# %% [markdown]
# # イベントデータ読み込み

# %%
input_dir = './data/'

# %%
df = pd.read_pickle(input_dir + 'a3_output_df.pkl')
df = df[df['形式'] == 'アタポン'].set_index('日付')
df
# Out:
#                               イベント       1位   2001位    形式   属性     期間
# 日付
# 2015-09-25           アタシポンコツアンドロイド   427777   78330  アタポン  NaN  249.0
# 2015-10-19             Nation Blue   324369   67627  アタポン  NaN  198.0
# 2015-11-20         Orange Sapphire   350000   42944  アタポン  NaN  150.0
# 2015-12-18              Snow Wings   520000   50954  アタポン  NaN  222.0
# 2016-01-20               パステルピンクな恋   602529   43854  アタポン  NaN  174.0
# 2016-02-18                オルゴールの小箱   523819   56737  アタポン  NaN  174.0
# 2016-03-20             絶対特権主張しますっ！   530000   51353  アタポン  NaN  174.0
# 2016-04-19                     つぼみ   666666   47907  アタポン  NaN  174.0
# 2016-05-19               明日また会えるよね   844167   58517  アタポン  NaN  198.0
# 2016-06-20                咲いてJewel   650152   77930  アタポン  NaN  174.0
# 2016-07-19                きみにいっぱい☆   615000   50759  アタポン  NaN  198.0
# 2016-08-19             Near to You   760307   46355  アタポン  NaN  198.0
# 2016-09-20                   ラブレター   596000  121303  アタポン  NaN  150.0
# 2016-10-20       Jet to the Future   609969   69430  アタポン  NaN  174.0
# 2016-11-19               Flip Flop   700000   64568  アタポン  NaN  198.0
# 2016-12-21               あんきら!?狂騒曲   694253   91619  アタポン  NaN  150.0
# 2017-01-20            Lunatic Show   684784  103834  アタポン  NaN  174.0
# 2017-02-17            情熱ファンファンファーレ   881000   87731  アタポン  NaN  198.0
# 2017-03-21                  ∀NSWER   715889   77131  アタポン  NaN  174.0
# 2017-04-19                Nocturne   711125   64224  アタポン  NaN  174.0
# 2017-05-19           モーレツ★世直しギルティ！   917400   85036  アタポン  NaN  222.0
# 2017-06-19       Yes！ Party Time！！   721149  102781  アタポン  NaN  174.0
# 2017-07-20     Kawaii make MY day！   775836   70863  アタポン  NaN  174.0
# 2017-08-21                  双翼の独奏歌   709450  156206  アタポン  NaN  150.0
# 2017-09-20            Twin☆くるっ★テール   807041  114084  アタポン  NaN  174.0
# 2017-10-20          Halloween♥Code   844167   89011  アタポン  NaN  174.0
# 2017-11-19           Trinity Field   783042  193847  アタポン  NaN  174.0
# 2017-12-20                 冬空プレシャス   765000   63299  アタポン  NaN  174.0
# 2018-01-12                美に入り彩を穿つ   748760  112616  アタポン  NaN  150.0
# 2018-02-19                   Frost   679865   93945  アタポン  NaN  150.0
# 2018-03-20              キラッ！満開スマイル   932639  144198  アタポン  NaN  198.0
# 2018-04-19        Spring Screaming   825782   67629  アタポン  NaN  174.0
# 2018-05-21              HARURUNRUN   751205   58907  アタポン  NaN  174.0
# 2018-06-19              エチュードは1曲だけ   817257   86964  アタポン  NaN  174.0
# 2018-07-19              SUN♡FLOWER   942493   74511  アタポン  NaN  198.0
# 2018-08-19              クレイジークレイジー   925686  163641  アタポン  NaN  198.0
# 2018-09-19             Pretty Liar   954312  224697  アタポン  NaN  198.0
# 2018-10-19            アンデッド・ダンスロック   974760   83532  アタポン  NaN  198.0
# 2018-11-19        Sunshine See May   945614  156519  アタポン  NaN  198.0
# 2018-12-19                Trust me   978776   78278  アタポン  NaN  198.0
# 2019-01-21               スパイスパラダイス   883242  179632  アタポン  NaN  174.0
# 2019-02-19            Needle Light   730000   67182  アタポン  NaN  150.0
# 2019-03-20                  未完成の歴史   886578  143192  アタポン  NaN  174.0
# 2019-04-19            きゅん・きゅん・まっくす   870742   73887  アタポン  NaN  174.0
# 2019-05-21                Max Beat   910638   68476  アタポン  NaN  174.0
# 2019-06-21  TAKAMARI☆CLIMAXXX！！！！！   936000   72590  アタポン  NaN  198.0
# 2019-07-22                    バベル   1059763  151703  アタポン  NaN  157.0
# 2019-08-20            comic cosmic  1129958   82849  アタポン  NaN  174.0
# 2019-09-20               ステップ＆スキップ  1161870  147582  アタポン  NaN  174.0
# 2019-10-21                  空想探査計画  1100000   71393  アタポン  NaN  174.0
# 2019-11-20         Secret Daybreak  1180231  169639  アタポン  NaN  175.0
# 2019-12-20           ギュっとMilky Way  1111111   99081  アタポン  NaN  174.0
# 2020-01-20             幸せの法則 ～ルール～  1268425  115890  アタポン  NaN  198.0
# 2020-02-18                      印象  1424681   76797  アタポン  NaN  198.0
# 2020-03-21            輝け！ビートシューター   1330000   84545  アタポン  NaN  198.0
# 2020-04-20               Athanasia  1130000   75775  アタポン  NaN  174.0
# 2020-05-19               不埒なCANVAS  1271125  188652  アタポン  NaN  198.0
# 2020-06-19      Sing the Prologue♪  1123140   85574  アタポン  NaN  174.0
# 2020-07-20                 太陽の絵の具箱  1120703  107142  アタポン  NaN  174.0
# 2020-08-19        ヒーローヴァーサスレイナンジョー  1250000   60211  アタポン  NaN  174.0

# %%
# プロットしてみる
fig = plt.figure()
ax = fig.add_subplot(111)
x = df.index
y = df.loc[:, '1位']
ax.plot(x, y)
plt.show()
# Out:
# WARNING:matplotlib.font_manager:findfont: Font family ['IPAMincho'] not found. Falling back to DejaVu Sans.

# %% [markdown]
# # stanデータ準備

# %%
# データ（辞書型）
dat = {
    'T':       len(df),         # 全日付の日数
    'y':       df['1位'].tolist(), # 観測値
}

# %%
# Stanコード
model = """
data {
  int T;                   // データ取得期間の長さ
  vector[T] y;       // 観測値
}
parameters {
  vector[T] mu;      // 水準+ドリフト成分の推定値
  vector[T] delta;   // ドリフト成分の推定値
  real<lower=0> s_w; // 水準成分の変動の大きさを表す標準偏差
  real<lower=0> s_z; // ドリフト成分の変動の大きさを表す標準偏差
  real<lower=0> s_v; // 観測誤差の標準偏差
}
model {
  for(i in 2:T){
    mu[i] ~ normal(mu[i-1] + delta[i-1], s_w);
    delta[i] ~ normal(delta[i-1], s_z);
    y[i] ~ normal(mu[i], s_v);
  }
}
"""

# %% [markdown]
# # Stan実行

# %%
# コンパイル
# %time stm = pystan.StanModel(model_code=model)
# Out:
# INFO:pystan:COMPILING THE C++ CODE FOR MODEL anon_model_6756962f483cdcec6d2c866a76ea3170 NOW.
# C:\Users\kazuy\Anaconda3\lib\site-packages\Cython\Compiler\Main.py:369: FutureWarning: Cython directive 'language_level' not set, using 2 for now (Py2). This will change in a later release! File: C:\Users\kazuy\AppData\Local\Temp\tmpvfra03j9\stanfit4anon_model_6756962f483cdcec6d2c866a76ea3170_2817580840647653134.pyx
#   tree = Parsing.p_module(s, pxd, full_module_name)
# Wall time: 22.3 s

# %%
# パラメータ設定
n_itr = 4000
n_warmup = n_itr - 1000
chains = 3

# %%
# 計算
# %time fit = stm.sampling(data=dat, iter=n_itr, chains=chains, n_jobs=-1, warmup=n_warmup, algorithm="NUTS", verbose=False)
# Out:
# Wall time: 33.6 s

# %%
# ファイル保存
save_dir = './data/'
with open(save_dir + 'c3_model.pickle', mode="wb") as f:
    pickle.dump(stm, f)
with open(save_dir + 'c3_fit.pickle', mode="wb") as f:
    pickle.dump(fit, f)
# Out:
# C:\Users\kazuy\Anaconda3\lib\site-packages\ipykernel_launcher.py:6: UserWarning: Pickling fit objects is an experimental feature!
# The relevant StanModel instance must be pickled along with this fit object.
# When unpickling the StanModel must be unpickled first.

# %% [markdown]
# # 結果確認

# %%
fit
# Out:
# Inference for Stan model: anon_model_6756962f483cdcec6d2c866a76ea3170.
# 3 chains, each with iter=4000; warmup=3000; thin=1;
# post-warmup draws per chain=1000, total post-warmup draws=3000.
#
#             mean se_mean     sd   2.5%    25%    50%    75%  97.5%  n_eff   Rhat
# mu[0]      3.2e5  3379.0  9.3e4  1.3e5  2.6e5  3.2e5  3.8e5  5.0e5    758    1.0
# mu[1]      3.6e5  2142.3  5.7e4  2.5e5  3.2e5  3.5e5  3.9e5  4.7e5    699    1.0
# mu[2]      4.0e5  2376.9  4.8e4  3.1e5  3.7e5  4.0e5  4.4e5  5.0e5    405    1.0
# mu[3]      4.9e5  1411.5  4.2e4  4.0e5  4.6e5  4.9e5  5.2e5  5.7e5    892    1.0
# mu[4]      5.4e5  2480.4  4.6e4  4.5e5  5.1e5  5.4e5  5.7e5  6.3e5    340    1.0
# mu[5]      5.5e5  1081.3  4.1e4  4.7e5  5.2e5  5.5e5  5.8e5  6.4e5   1468    1.0
# mu[6]      5.8e5  2325.3  4.5e4  4.9e5  5.5e5  5.8e5  6.1e5  6.7e5    368    1.0
# mu[7]      6.5e5  1321.2  4.1e4  5.7e5  6.3e5  6.5e5  6.8e5  7.3e5    960    1.0
# mu[8]      7.2e5  5825.2  6.0e4  6.1e5  6.7e5  7.1e5  7.5e5  8.4e5    106   1.01
# mu[9]      6.8e5  754.29  4.1e4  5.9e5  6.5e5  6.7e5  7.0e5  7.6e5   3000    1.0
# mu[10]     6.6e5  2024.5  4.1e4  5.9e5  6.3e5  6.6e5  6.9e5  7.4e5    412    1.0
# mu[11]     6.9e5  2493.5  4.5e4  6.0e5  6.6e5  6.9e5  7.2e5  7.8e5    331    1.0
# mu[12]     6.5e5  2483.4  4.4e4  5.7e5  6.2e5  6.5e5  6.8e5  7.4e5    312    1.0
# mu[13]     6.5e5  2418.2  4.3e4  5.7e5  6.2e5  6.5e5  6.9e5  7.4e5    316    1.0
# mu[14]     6.9e5  754.82  4.1e4  6.0e5  6.6e5  6.9e5  7.1e5  7.7e5   3000    1.0
# mu[15]     7.0e5  728.96  4.0e4  6.2e5  6.8e5  7.0e5  7.3e5  7.8e5   3000    1.0
# mu[16]     7.2e5  739.96  4.1e4  6.4e5  7.0e5  7.2e5  7.5e5  8.1e5   3000    1.0
# mu[17]     7.8e5  4345.1  5.2e4  6.8e5  7.4e5  7.7e5  8.1e5  8.9e5    145   1.01
# mu[18]     7.5e5  744.17  4.1e4  6.8e5  7.2e5  7.5e5  7.8e5  8.3e5   3000    1.0
# mu[19]     7.6e5  1706.5  4.2e4  6.8e5  7.3e5  7.6e5  7.9e5  8.4e5    610    1.0
# mu[20]     8.1e5  4333.0  5.3e4  7.2e5  7.7e5  8.1e5  8.4e5  9.2e5    148   1.01
# mu[21]     7.7e5  777.32  4.3e4  6.9e5  7.4e5  7.7e5  7.9e5  8.5e5   3000    1.0
# mu[22]     7.7e5  750.43  4.1e4  6.9e5  7.4e5  7.7e5  8.0e5  8.5e5   3000    1.0
# mu[23]     7.6e5  2371.6  4.4e4  6.7e5  7.3e5  7.6e5  7.9e5  8.4e5    338    1.0
# mu[24]     7.9e5  744.78  4.1e4  7.0e5  7.6e5  7.9e5  8.1e5  8.6e5   3000    1.0
# mu[25]     8.0e5  2096.8  4.3e4  7.2e5  7.7e5  8.0e5  8.3e5  8.9e5    423    1.0
# mu[26]     7.8e5  748.21  4.1e4  7.0e5  7.6e5  7.8e5  8.1e5  8.6e5   3000    1.0
# mu[27]     7.7e5  743.37  4.1e4  6.9e5  7.5e5  7.7e5  8.0e5  8.5e5   3000    1.0
# mu[28]     7.6e5  758.26  4.2e4  6.8e5  7.4e5  7.6e5  7.9e5  8.5e5   3000    1.0
# mu[29]     7.6e5  3471.9  4.8e4  6.7e5  7.3e5  7.7e5  8.0e5  8.5e5    192   1.01
# mu[30]     8.4e5  3677.5  4.8e4  7.5e5  8.0e5  8.3e5  8.7e5  9.3e5    172   1.01
# mu[31]     8.2e5   726.6  4.0e4  7.5e5  8.0e5  8.2e5  8.5e5  9.1e5   3000    1.0
# mu[32]     8.1e5  2627.5  4.5e4  7.3e5  7.8e5  8.1e5  8.4e5  9.0e5    289    1.0
# mu[33]     8.5e5  750.83  4.1e4  7.7e5  8.2e5  8.5e5  8.7e5  9.3e5   3000    1.0
# mu[34]     9.0e5  2108.1  4.3e4  8.1e5  8.7e5  9.0e5  9.3e5  9.9e5    423    1.0
# mu[35]     9.2e5  1209.9  4.3e4  8.4e5  8.9e5  9.2e5  9.4e5  1.0e6   1256    1.0
# mu[36]     9.4e5  2405.4  4.3e4  8.5e5  9.1e5  9.4e5  9.7e5  1.0e6    327   1.01
# mu[37]     9.5e5  2606.5  4.4e4  8.6e5  9.1e5  9.5e5  9.8e5  1.0e6    279    1.0
# mu[38]     9.4e5  2413.7  4.2e4  8.6e5  9.1e5  9.4e5  9.7e5  1.0e6    309   1.01
# mu[39]     9.3e5  2666.2  4.3e4  8.5e5  9.0e5  9.3e5  9.6e5  1.0e6    264    1.0
# mu[40]     8.9e5  735.87  4.0e4  8.1e5  8.6e5  8.9e5  9.1e5  9.7e5   3000    1.0
# mu[41]     8.4e5  5184.7  5.7e4  7.2e5  8.0e5  8.5e5  8.8e5  9.4e5    121   1.01
# mu[42]     8.8e5  1204.6  4.2e4  7.9e5  8.5e5  8.8e5  9.0e5  9.6e5   1215    1.0
# mu[43]     9.0e5  1455.6  4.3e4  8.1e5  8.7e5  9.0e5  9.2e5  9.8e5    867    1.0
# mu[44]     9.3e5  1304.0  4.2e4  8.5e5  9.0e5  9.3e5  9.6e5  1.0e6   1046    1.0
# mu[45]     9.7e5  1578.2  4.3e4  8.8e5  9.4e5  9.7e5  1.0e6  1.0e6    728    1.0
# mu[46]     1.0e6  1475.8  4.0e4  9.6e5  1.0e6  1.0e6  1.1e6  1.1e6    740    1.0
# mu[47]     1.1e6  2078.4  4.3e4  1.0e6  1.1e6  1.1e6  1.1e6  1.2e6    429    1.0
# mu[48]     1.1e6  1696.6  4.2e4  1.0e6  1.1e6  1.1e6  1.2e6  1.2e6    610    1.0
# mu[49]     1.1e6  734.88  4.0e4  1.1e6  1.1e6  1.1e6  1.2e6  1.2e6   3000    1.0
# mu[50]     1.2e6   736.6  4.0e4  1.1e6  1.1e6  1.2e6  1.2e6  1.2e6   3000    1.0
# mu[51]     1.2e6  2822.7  4.5e4  1.1e6  1.1e6  1.2e6  1.2e6  1.3e6    256    1.0
# mu[52]     1.2e6  1332.7  4.3e4  1.2e6  1.2e6  1.2e6  1.3e6  1.3e6   1018    1.0
# mu[53]     1.3e6  5781.0  6.2e4  1.2e6  1.3e6  1.3e6  1.3e6  1.4e6    114   1.01
# mu[54]     1.3e6  2962.4  4.8e4  1.2e6  1.2e6  1.3e6  1.3e6  1.4e6    266    1.0
# mu[55]     1.2e6  3348.6  4.8e4  1.1e6  1.2e6  1.2e6  1.2e6  1.3e6    204   1.01
# mu[56]     1.2e6  1324.9  4.3e4  1.1e6  1.2e6  1.2e6  1.3e6  1.3e6   1041   1.01
# mu[57]     1.2e6  2827.4  4.7e4  1.1e6  1.1e6  1.2e6  1.2e6  1.3e6    276    1.0
# mu[58]     1.2e6  2727.1  5.0e4  1.1e6  1.1e6  1.2e6  1.2e6  1.3e6    330    1.0
# mu[59]     1.2e6  2375.0  5.4e4  1.1e6  1.2e6  1.2e6  1.3e6  1.3e6    524    1.0
# delta[0]   3.4e4  2402.3  3.0e4 -1.5e4  1.5e4  3.0e4  4.9e4  1.1e5    155   1.01
# delta[1]   3.4e4  2364.6  2.7e4 -1.0e4  1.6e4  3.0e4  4.9e4  9.7e4    131   1.01
# delta[2]   3.4e4  2337.5  2.5e4  -7992  1.7e4  3.1e4  4.8e4  9.1e4    114   1.01
# delta[3]   3.2e4  1951.8  2.3e4  -7601  1.6e4  2.9e4  4.5e4  8.3e4    137   1.01
# delta[4]   2.9e4  1617.4  2.1e4  -8509  1.6e4  2.8e4  4.2e4  7.5e4    169   1.02
# delta[5]   2.8e4  1250.8  2.0e4  -8379  1.5e4  2.6e4  3.9e4  7.2e4    253   1.01
# delta[6]   2.6e4  1057.3  1.9e4  -8848  1.4e4  2.5e4  3.7e4  6.9e4    338   1.01
# delta[7]   2.3e4  829.01  1.9e4 -1.2e4  1.2e4  2.2e4  3.3e4  6.3e4    498   1.01
# delta[8]   1.8e4  897.17  1.8e4 -1.9e4 8586.1  1.8e4  2.9e4  5.7e4    422   1.01
# delta[9]   1.6e4  1222.7  1.9e4 -2.4e4 5701.5  1.6e4  2.6e4  5.4e4    234   1.01
# delta[10]  1.5e4  1304.0  1.8e4 -2.3e4 4621.9  1.5e4  2.5e4  5.1e4    201   1.01
# delta[11]  1.3e4  1502.2  1.9e4 -2.8e4 2922.0  1.4e4  2.4e4  5.0e4    156   1.02
# delta[12]  1.4e4  1211.8  1.8e4 -2.4e4 4195.8  1.4e4  2.4e4  5.0e4    212   1.02
# delta[13]  1.5e4  880.02  1.7e4 -1.8e4 5292.3  1.5e4  2.5e4  5.0e4    372   1.01
# delta[14]  1.5e4  811.88  1.7e4 -1.8e4 6282.4  1.5e4  2.5e4  5.0e4    423   1.01
# delta[15]  1.6e4  811.87  1.7e4 -1.9e4 6051.6  1.5e4  2.4e4  5.4e4    435   1.01
# delta[16]  1.5e4  790.45  1.7e4 -1.8e4 5727.0  1.5e4  2.4e4  5.1e4    438   1.01
# delta[17]  1.3e4  868.11  1.7e4 -2.1e4 3503.0  1.3e4  2.3e4  4.8e4    370   1.01
# delta[18]  1.2e4  921.83  1.7e4 -2.2e4 2635.2  1.2e4  2.2e4  4.9e4    336   1.01
# delta[19]  1.2e4  925.39  1.7e4 -2.3e4 1799.1  1.2e4  2.1e4  4.6e4    337   1.01
# delta[20] 9494.8  1348.9  1.8e4 -2.6e4 266.58  1.1e4  2.0e4  4.6e4    172    1.0
# delta[21] 9175.6  1426.2  1.8e4 -2.9e4 -655.0  1.0e4  2.0e4  4.2e4    153   1.01
# delta[22] 9189.0  1263.1  1.7e4 -2.9e4 -572.9  1.0e4  2.0e4  4.3e4    188   1.01
# delta[23] 9816.2  1181.1  1.7e4 -2.6e4 217.47  1.1e4  2.0e4  4.4e4    203   1.01
# delta[24] 9816.3  1198.1  1.7e4 -2.6e4 387.05  1.1e4  2.0e4  4.3e4    205   1.01
# delta[25] 9434.7  1312.5  1.7e4 -2.8e4  395.6  1.1e4  1.9e4  4.3e4    172   1.01
# delta[26] 9228.4  1274.6  1.7e4 -2.9e4 -285.8  1.0e4  1.9e4  4.4e4    186   1.01
# delta[27]  1.0e4  1071.2  1.7e4 -2.5e4 1520.2  1.1e4  2.0e4  4.4e4    247   1.01
# delta[28]  1.2e4  807.77  1.6e4 -2.1e4 3301.0  1.3e4  2.1e4  4.4e4    393   1.01
# delta[29]  1.4e4  682.74  1.6e4 -1.8e4 4977.3  1.4e4  2.3e4  4.9e4    556   1.01
# delta[30]  1.4e4  607.49  1.6e4 -1.9e4 4457.6  1.4e4  2.3e4  4.7e4    688   1.01
# delta[31]  1.4e4  720.75  1.6e4 -1.9e4 4991.5  1.4e4  2.3e4  4.9e4    519   1.01
# delta[32]  1.6e4  813.44  1.7e4 -1.7e4 5800.7  1.5e4  2.4e4  5.3e4    439   1.01
# delta[33]  1.6e4   889.0  1.7e4 -1.5e4 6699.9  1.5e4  2.5e4  5.2e4    347   1.01
# delta[34]  1.5e4  756.02  1.6e4 -1.6e4 6030.1  1.4e4  2.4e4  5.0e4    451   1.01
# delta[35]  1.3e4  666.21  1.6e4 -1.8e4 4083.4  1.4e4  2.2e4  4.9e4    582   1.01
# delta[36]  1.1e4  876.62  1.6e4 -2.1e4 2212.9  1.2e4  2.1e4  4.4e4    334   1.01
# delta[37] 9575.2  1248.9  1.7e4 -2.8e4 452.53  1.1e4  1.9e4  4.2e4    189   1.01
# delta[38] 8272.6  1570.9  1.8e4 -3.3e4 -995.8  1.0e4  1.9e4  4.0e4    136   1.01
# delta[39] 7805.7  1661.1  1.8e4 -3.5e4 -935.0  1.0e4  1.9e4  4.1e4    123   1.01
# delta[40] 9528.2  1315.0  1.7e4 -3.0e4 484.46  1.1e4  2.0e4  4.1e4    171   1.01
# delta[41]  1.3e4  646.39  1.6e4 -2.1e4 4659.6  1.4e4  2.2e4  4.5e4    612    1.0
# delta[42]  1.7e4  581.65  1.6e4 -1.6e4 7377.0  1.6e4  2.5e4  5.2e4    772    1.0
# delta[43]  2.0e4  815.83  1.7e4 -1.3e4 9238.1  1.8e4  2.8e4  5.8e4    438   1.01
# delta[44]  2.2e4  1437.4  1.8e4 -1.1e4  1.1e4  2.0e4  3.2e4  6.5e4    161   1.02
# delta[45]  2.4e4  1779.9  1.9e4  -9040  1.1e4  2.1e4  3.4e4  7.0e4    117   1.03
# delta[46]  2.3e4  1700.5  1.9e4  -8646  1.2e4  2.1e4  3.3e4  6.7e4    121   1.02
# delta[47]  2.2e4  1495.4  1.8e4  -8955  1.1e4  2.0e4  3.2e4  6.3e4    143   1.02
# delta[48]  2.1e4  1301.5  1.7e4 -1.2e4 9974.7  1.9e4  3.0e4  5.7e4    175   1.02
# delta[49]  2.0e4  1078.3  1.7e4 -1.2e4 9070.1  1.9e4  2.9e4  5.8e4    262   1.01
# delta[50]  1.9e4  859.45  1.7e4 -1.3e4 8275.7  1.8e4  2.8e4  5.8e4    414   1.01
# delta[51]  1.8e4  820.16  1.8e4 -1.4e4 7378.2  1.7e4  2.7e4  5.8e4    459   1.01
# delta[52]  1.6e4  596.15  1.7e4 -1.8e4 5741.6  1.5e4  2.5e4  5.3e4    832    1.0
# delta[53]  1.1e4  764.03  1.8e4 -2.8e4  700.3  1.1e4  2.1e4  4.6e4    580    1.0
# delta[54] 7100.3  1572.4  2.0e4 -3.8e4  -3476 9165.6  1.9e4  4.2e4    160    1.0
# delta[55] 6512.3  1692.4  2.1e4 -3.9e4  -4881 8846.7  2.0e4  4.3e4    153    1.0
# delta[56] 5830.8  1837.1  2.2e4 -4.4e4  -6353 8265.2  1.9e4  4.5e4    145    1.0
# delta[57] 6949.1  1603.9  2.3e4 -4.5e4  -5315 8770.9  2.1e4  4.9e4    211    1.0
# delta[58] 7895.3  1488.3  2.5e4 -4.7e4  -4919 9516.6  2.2e4  5.6e4    281    1.0
# delta[59] 8298.2  1473.3  2.7e4 -4.8e4  -5497  1.0e4  2.3e4  6.1e4    334    1.0
# s_w        5.4e4  3362.2  2.5e4 6856.2  3.8e4  5.3e4  6.8e4  1.1e5     55   1.01
# s_z       8838.2  1175.6 6955.0 1071.9 3492.4 6773.5  1.2e4  2.6e4     35   1.04
# s_v        6.8e4  2103.2  1.8e4  1.5e4  6.1e4  7.1e4  8.0e4  9.6e4     72   1.02
# lp__       -1861    8.26  46.75  -1950  -1896  -1862  -1828  -1771     32   1.04
#
# Samples were drawn using NUTS at Thu Nov 19 12:53:16 2020.
# For each parameter, n_eff is a crude measure of effective sample size,
# and Rhat is the potential scale reduction factor on split chains (at
# convergence, Rhat=1).

# %%
fit.plot()
# Out:
# WARNING:matplotlib.font_manager:findfont: Font family ['IPAMincho'] not found. Falling back to DejaVu Sans.

# %%
#結果を抽出
ms = fit.extract() 

#muの事後平均を算出
mu_mean = ms['mu'].mean(axis=0)

#95パーセンタイルを抽出
mu_5 = np.array(pd.DataFrame(ms['mu']).apply(lambda x: np.percentile(x, 5), axis=0))
mu_95 = np.array(pd.DataFrame(ms['mu']).apply(lambda x: np.percentile(x, 95), axis=0))

# delta
# 事後平均
delta_mean = ms['delta'].mean(axis=0)
# #95パーセンタイル抽出
delta_5 = np.array(pd.DataFrame(ms['delta']).apply(lambda x: np.percentile(x, 5), axis=0))
delta_95 = np.array(pd.DataFrame(ms['delta']).apply(lambda x: np.percentile(x, 95), axis=0))

#x軸
X = df.index

# %%
fig = plt.figure()
ax = fig.add_subplot(111)

ax.plot(X, df['1位'], label='observed')
# ax.plot(X, mu, label='true trend', c='green')
ax.plot(X, mu_mean, label='predicted trend', c='red')
plt.fill_between(X, mu_5, mu_95, color='red', alpha=0.2)
# plt.legend(loc='upper left', borderaxespad=0, fontsize=15)
plt.show()

# %%
# delta
fig = plt.figure()
ax = fig.add_subplot(111)

ax.plot(X, delta_mean, label='predicted trend', c='red')
plt.fill_between(X, delta_5, delta_95, color='red', alpha=0.2)
plt.show()

# %% [markdown]
# * やはり、平滑化トレンドの滑らかさとローカルトレンドのガタガタの中間くらいになってる
# * トレンドの変化は以下のようなものによると考えられるので、実際はローカル線形トレンドモデルが一番良く表せると思われる
#   * プレイヤーの数の変化（滑らかな変化）
#   * キャラの性能の変化（滑らかな変化）
#   * グランドライブなど、新機能の実装（急な変化）

# %% [markdown]
# # 残差確認

# %%
df['predict'] = mu_mean
# 予測とのズレ（比）
df['diff'] = df['1位'] - df['predict']
df.drop(['2001位', '形式', '属性'], axis=1, inplace=True)
# Out:
# INFO:numexpr.utils:NumExpr defaulting to 6 threads.

# %%
df.head()
# Out:
#                        イベント      1位     期間        predict           diff
# 日付
# 2015-09-25    アタシポンコツアンドロイド  427777  249.0  321039.392096  106737.607904
# 2015-10-19      Nation Blue  324369  198.0  355165.454138  -30796.454138
# 2015-11-20  Orange Sapphire  350000  150.0  401509.591084  -51509.591084
# 2015-12-18       Snow Wings  520000  222.0  485807.819149   34192.180851
# 2016-01-20        パステルピンクな恋  602529  174.0  542728.005889   59800.994111

# %%
# 決定係数 (R2)
r2_score(df['1位'], df['predict'])
# Out:
# 0.9497272056386685

# %%
fig, ax = plt.subplots(1, 1)
ax.scatter(df['1位'], df['predict'])
ideal_min = min(df['1位'].min(), df['predict'].min())
ideal_max = min(df['1位'].max(), df['predict'].max())
ax.plot([ideal_min, ideal_max], [ideal_min, ideal_max], color='r')
plt.show()

# %%
df.corr()
# Out:
#                1位        期間   predict      diff
# 1位       1.000000  0.100235  0.974639  0.275262
# 期間       0.100235  1.000000 -0.045059  0.640845
# predict  0.974639 -0.045059  1.000000  0.053141
# diff     0.275262  0.640845  0.053141  1.000000

# %%
# 期間と相関あり
sns.set(font='Yu Gothic')
sns.pairplot(df)
